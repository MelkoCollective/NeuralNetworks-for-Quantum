# %%
import numpy as np
import matplotlib.pyplot as plt
import random

#L=4
exact_energy = -0.4534132086591546

# %%
def FigPlot(qmc_energy,vmc_energy,qmc_vmc_energy):

    fig = plt.figure(1,figsize=(6,4), dpi=120, facecolor='w', edgecolor='k')
 
    plt.plot(vmc_energy,marker='o',markersize=2,linewidth=0.0,markevery=1,label="VMC")
    plt.plot(qmc_energy,marker='s',markersize=2,linewidth=0.0,markevery=1,label="QMC")
    plt.plot(qmc_vmc_energy,marker='^',markersize=2,linewidth=0.0,markevery=1,label="200 epochs QMC, 3800 epochs VMC")

    plt.hlines(exact_energy,0, 4000 ,linestyle="--",label="Exact")  
    plt.vlines(200,-0.5,-0.2,linestyle="--",label="QMC to VMC transition")


    plt.xlabel("Step",fontsize=15)
    plt.ylabel("$\\langle H \\rangle$",fontsize=20)
    #plt.title("{} sites".format(N))
    plt.legend(loc="best")
    #plt.xlim(200,500)
    plt.ylim(-0.5,-0.2)

    plt.show()

# %%
a_file = open("nh8/QMC_Full/E_QMC_4_8.dat", "r")
qmc_1 = np.loadtxt(a_file)
a_file.close()

a_file = open("nh8/VMC_Full/E_VMC_4_8.dat", "r")
vmc_1 = np.loadtxt(a_file)
a_file.close()

a_file = open("nh8/QMC_VMC/E_QMC_VMC_4_8.dat", "r")
qmc_vmc_1 = np.loadtxt(a_file)
a_file.close()

FigPlot(qmc_1,vmc_1,qmc_vmc_1)

# %%
a_file = open("nh16/QMC_Full/E_QMC_4_16.dat", "r")
qmc_2 = np.loadtxt(a_file)
a_file.close()

a_file = open("nh16/VMC_Full/E_VMC_4_16.dat", "r")
vmc_2 = np.loadtxt(a_file)
a_file.close()

a_file = open("nh16/QMC_VMC/E_QMC_VMC_4_16.dat", "r")
qmc_vmc_2 = np.loadtxt(a_file)
a_file.close()

FigPlot(qmc_2,vmc_2,qmc_vmc_2)

# %%
a_file = open("nh24/QMC_Full/E_QMC_4_24.dat", "r")
qmc_3 = np.loadtxt(a_file)
a_file.close()

a_file = open("nh24/VMC_Full/E_VMC_4_24.dat", "r")
vmc_3 = np.loadtxt(a_file)
a_file.close()

a_file = open("nh24/QMC_VMC/E_QMC_VMC_4_24.dat", "r")
qmc_vmc_3 = np.loadtxt(a_file)
a_file.close()

FigPlot(qmc_3,vmc_3,qmc_vmc_3)

# %%
a_file = open("nh32/QMC_Full/E_QMC_4_32.dat", "r")
qmc_4 = np.loadtxt(a_file)
a_file.close()

a_file = open("nh32/VMC_Full/E_VMC_4_32.dat", "r")
vmc_4 = np.loadtxt(a_file)
a_file.close()

a_file = open("nh32/QMC_VMC/E_QMC_VMC_4_32.dat", "r")
qmc_vmc_4 = np.loadtxt(a_file)
a_file.close()

FigPlot(qmc_4,vmc_4,qmc_vmc_4)

# %%
a_file = open("nh40/QMC_Full/E_QMC_4_40.dat", "r")
qmc_5 = np.loadtxt(a_file)
a_file.close()

a_file = open("nh40/VMC_Full/E_VMC_4_40.dat", "r")
vmc_5 = np.loadtxt(a_file)
a_file.close()

a_file = open("nh40/QMC_VMC/E_QMC_VMC_4_40.dat", "r")
qmc_vmc_5 = np.loadtxt(a_file)
a_file.close()

FigPlot(qmc_5,vmc_5,qmc_vmc_5)
