# %%
import numpy as np
import matplotlib.pyplot as plt

exactE_4     = -0.4534132086591546
exactE_8     = -0.40518005298872917
exactE_12    = -0.3884864748124427
exactE_16    = -0.380514770608724

# %% [markdown]
# # Read in Data

# %%
# 4x4, lr = 0.001
E_QMC_4_8_fd    = np.loadtxt("experiments/4x4/nh8/QMC_Full/E_QMC_4_8_fulldata.dat")
E_QMC_4_16_fd   = np.loadtxt("experiments/4x4/nh16/QMC_Full/E_QMC_4_16_fulldata.dat")
E_QMC_4_24_fd   = np.loadtxt("experiments/4x4/nh24/QMC_Full/E_QMC_4_24_fulldata.dat")
E_QMC_4_32_fd   = np.loadtxt("experiments/4x4/nh32/QMC_Full/E_QMC_4_32_fulldata.dat")
E_QMC_4_40_fd   = np.loadtxt("experiments/4x4/nh40/QMC_Full/E_QMC_4_40_fulldata.dat")

# 8x8, lr = 0.001
E_QMC_8_8_fd    = np.loadtxt("experiments/8x8/nh8/QMC_Full/E_QMC_8_8_fulldata.dat")
E_QMC_8_16_fd   = np.loadtxt("experiments/8x8/nh16/QMC_Full/E_QMC_8_16_fulldata.dat")
E_QMC_8_24_fd   = np.loadtxt("experiments/8x8/nh24/QMC_Full/E_QMC_8_24_fulldata.dat")
E_QMC_8_32_fd   = np.loadtxt("experiments/8x8/nh32/QMC_Full/E_QMC_8_32_fulldata.dat")
E_QMC_8_40_fd   = np.loadtxt("experiments/8x8/nh40/QMC_Full/E_QMC_8_40_fulldata.dat")

# 12x12, lr = 0.001
E_QMC_12_8_fd    = np.loadtxt("experiments/12x12/nh8/QMC_Full/E_QMC_12_8_fulldata.dat")
E_QMC_12_16_fd   = np.loadtxt("experiments/12x12/nh16/QMC_Full/E_QMC_12_16_fulldata.dat")
E_QMC_12_24_fd   = np.loadtxt("experiments/12x12/nh24/QMC_Full/E_QMC_12_24_fulldata.dat")
E_QMC_12_32_fd   = np.loadtxt("experiments/12x12/nh32/QMC_Full/E_QMC_12_32_fulldata.dat")
E_QMC_12_40_fd   = np.loadtxt("experiments/12x12/nh40/QMC_Full/E_QMC_12_40_fulldata.dat")

# 16x16, lr = 0.001
E_QMC_16_8_fd    = np.loadtxt("experiments/16x16/nh8/QMC_Full/E_QMC_16_8_fulldata.dat")
E_QMC_16_16_fd   = np.loadtxt("experiments/16x16/nh16/QMC_Full/E_QMC_16_16_fulldata.dat")
E_QMC_16_24_fd   = np.loadtxt("experiments/16x16/nh24/QMC_Full/E_QMC_16_24_fulldata.dat")
E_QMC_16_32_fd   = np.loadtxt("experiments/16x16/nh32/QMC_Full/E_QMC_16_32_fulldata.dat")
E_QMC_16_40_fd   = np.loadtxt("experiments/16x16/nh40/QMC_Full/E_QMC_16_40_fulldata.dat")

# %% [markdown]
# # Energy Plotting Function

# %%
def QMCPlot(N,lr,exactE,qmc_8,qmc_16,qmc_24,qmc_32,qmc_40,xlim,ylim):

    fig = plt.figure(1,figsize=(6,4), dpi=120, facecolor='w', edgecolor='k')
    
    plt.plot(qmc_8,marker='o',markersize=1,linewidth=0.0,markevery=1,label="nh = 8")
    plt.plot(qmc_16,marker='o',markersize=1,linewidth=0.0,markevery=1,label="nh = 16")
    plt.plot(qmc_24,marker='o',markersize=1,linewidth=0.0,markevery=1,label="nh = 24")
    plt.plot(qmc_32,marker='o',markersize=1,linewidth=0.0,markevery=1,label="nh = 32")
    plt.plot(qmc_40,marker='o',markersize=1,linewidth=0.0,markevery=1,label="nh = 40")

    plt.hlines(exactE,0, 1000 ,linestyle="--",label="Exact")

    plt.xlabel("Step",fontsize=15)
    plt.ylabel("$\\langle H \\rangle$",fontsize=20)
    plt.title("{} x {} Lattice, Learning Rate = {}".format(N,N,lr))
    plt.legend(loc="best")
    plt.xlim(xlim[0],xlim[1])
    plt.ylim(ylim[0],ylim[1])

    plt.show()

# %% [markdown]
# # Plot all nh values for each system size (for both lr)

# %% [markdown]
# ### 4x4, lr = 0.001

# %%
QMCPlot(4,0.001,exactE_4,E_QMC_4_8_fd,E_QMC_4_16_fd,E_QMC_4_24_fd,E_QMC_4_32_fd,E_QMC_4_40_fd,[0,1000],[-0.5,-0.4])

# %% [markdown]
# ### 8x8, lr = 0.001

# %%
QMCPlot(8,0.001,exactE_8,E_QMC_8_8_fd,E_QMC_8_16_fd,E_QMC_8_24_fd,E_QMC_8_32_fd,E_QMC_8_40_fd,[0,1000],[-0.5,-0.2])

# %% [markdown]
# ### 12x12, lr = 0.001

# %%
QMCPlot(12,0.001,exactE_12,E_QMC_12_8_fd,E_QMC_12_16_fd,E_QMC_12_24_fd,E_QMC_12_32_fd,E_QMC_12_40_fd,[0,1000],[-0.5,-0.2])

# %% [markdown]
# ### 16x16, lr = 0.001
