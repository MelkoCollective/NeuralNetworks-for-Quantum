# %%
import numpy as np
import matplotlib.pyplot as plt
import random

#L=4
exact_energy = -0.40518005298872917

# %%
def FigPlot(qmc_energy,vmc_energy,qmc_vmc_energy,qmc_energy_small,vmc_energy_small,qmc_vmc_energy_small):

    fig = plt.figure(1,figsize=(6,4), dpi=120, facecolor='w', edgecolor='k')
 
    #plt.plot(vmc_energy,marker='o',markersize=2,linewidth=0.0,markevery=1,label="VMC, lr=0.01")
    #plt.plot(qmc_energy,marker='s',markersize=2,linewidth=0.0,markevery=1,label="QMC, lr=0.01")
    #plt.plot(qmc_vmc_energy,marker='^',markersize=2,linewidth=0.0,markevery=1,label="QMC and VMC, lr=0.01")
    plt.plot(vmc_energy_small,marker='o',markersize=2,linewidth=0.0,markevery=1,label="VMC, lr=0.001")
    plt.plot(qmc_energy_small,marker='s',markersize=2,linewidth=0.0,markevery=1,label="QMC, lr=0.001")
    plt.plot(qmc_vmc_energy_small,marker='s',markersize=2,linewidth=0.0,markevery=1,label="QMC and VMC, lr=0.001")

    plt.hlines(exact_energy,0, 4000 ,linestyle="--",label="Exact") 
    plt.vlines(200,-0.5,-0.2,linestyle="--",color='r',label="QMC VMC transition")

    plt.xlabel("Step",fontsize=15)
    plt.ylabel("$\\langle H \\rangle$",fontsize=20)
    #plt.title("{} sites".format(N))
    plt.legend(loc="best")
    #plt.xlim(200,500)
    plt.ylim(-0.5,-0.2)

    plt.show()

# %%
def FigPlot_2(qmc_energy,vmc_energy,qmc_vmc_energy):

    fig = plt.figure(1,figsize=(6,4), dpi=120, facecolor='w', edgecolor='k')
 
    plt.plot(vmc_energy,marker='o',markersize=2,linewidth=0.0,markevery=1,label="VMC, lr=0.01")
    plt.plot(qmc_energy,marker='s',markersize=2,linewidth=0.0,markevery=1,label="QMC, lr=0.01")
    plt.plot(qmc_vmc_energy,marker='^',markersize=2,linewidth=0.0,markevery=1,label="QMC and VMC, lr=0.01")

    plt.hlines(exact_energy,0, 4000 ,linestyle="--",label="Exact")      
    plt.vlines(200,-0.5,-0.2,linestyle="--",color='r',label="QMC VMC transition")

    plt.xlabel("Step",fontsize=15)
    plt.ylabel("$\\langle H \\rangle$",fontsize=20)
    #plt.title("{} sites".format(N))
    plt.legend(loc="best")
    #plt.xlim(200,500)
    plt.ylim(-0.5,-0.2)

    plt.show()

# %% [markdown]
# # 8x8, nh=8

# %%
a_file = open("nh8/QMC_Full/E_QMC_8_8.dat", "r")
qmc_1 = np.loadtxt(a_file)
a_file.close()

a_file = open("nh8/VMC_Full/E_VMC_8_8.dat", "r")
vmc_1 = np.loadtxt(a_file)
a_file.close()

a_file = open("nh8/QMC_VMC/E_QMC_VMC_8_8.dat", "r")
qmc_vmc_1 = np.loadtxt(a_file)
a_file.close()

# load smaller learning rate data for comparison
a_file = open("../../experiments/8x8/nh8/QMC_Full/E_QMC_8_8.dat", "r")
qmc_1_small = np.loadtxt(a_file)
a_file.close()

a_file = open("../../experiments/8x8/nh8/VMC_Full/E_VMC_8_8.dat", "r")
vmc_1_small = np.loadtxt(a_file)
a_file.close()

a_file = open("../../experiments/8x8/nh8/QMC_VMC/E_QMC_VMC_8_8.dat", "r")
qmc_vmc_1_small = np.loadtxt(a_file)
a_file.close()

FigPlot(qmc_1,vmc_1,qmc_vmc_1,qmc_1_small,vmc_1_small,qmc_vmc_1_small)
FigPlot_2(qmc_1,vmc_1,qmc_vmc_1)

# %% [markdown]
# # 8x8, nh=16

# %%
a_file = open("nh16/QMC_Full/E_QMC_8_16.dat", "r")
qmc_2 = np.loadtxt(a_file)
a_file.close()

a_file = open("nh16/VMC_Full/E_VMC_8_16.dat", "r")
vmc_2 = np.loadtxt(a_file)
a_file.close()

a_file = open("nh16/QMC_VMC/E_QMC_VMC_8_16.dat", "r")
qmc_vmc_2 = np.loadtxt(a_file)
a_file.close()

# load smaller learning rate data for comparison
a_file = open("../../experiments/8x8/nh16/QMC_Full/E_QMC_8_16.dat", "r")
qmc_2_small = np.loadtxt(a_file)
a_file.close()

a_file = open("../../experiments/8x8/nh16/VMC_Full/E_VMC_8_16.dat", "r")
vmc_2_small = np.loadtxt(a_file)
a_file.close()

a_file = open("../../experiments/8x8/nh16/QMC_VMC/E_QMC_VMC_8_16.dat", "r")
qmc_vmc_2_small = np.loadtxt(a_file)
a_file.close()

FigPlot(qmc_2,vmc_2,qmc_vmc_2,qmc_2_small,vmc_2_small,qmc_vmc_2_small)
FigPlot_2(qmc_2,vmc_2,qmc_vmc_2)

# %% [markdown]
# # 8x8, nh=24

# %%
a_file = open("nh24/QMC_Full/E_QMC_8_24.dat", "r")
qmc_3 = np.loadtxt(a_file)
a_file.close()

a_file = open("nh24/VMC_Full/E_VMC_8_24.dat", "r")
vmc_3 = np.loadtxt(a_file)
a_file.close()

a_file = open("nh24/QMC_VMC/E_QMC_VMC_8_24.dat", "r")
qmc_vmc_3 = np.loadtxt(a_file)
a_file.close()

# load smaller learning rate data for comparison
a_file = open("../../experiments/8x8/nh24/QMC_Full/E_QMC_8_24.dat", "r")
qmc_3_small = np.loadtxt(a_file)
a_file.close()

a_file = open("../../experiments/8x8/nh24/VMC_Full/E_VMC_8_24.dat", "r")
vmc_3_small = np.loadtxt(a_file)
a_file.close()

a_file = open("../../experiments/8x8/nh24/QMC_VMC/E_QMC_VMC_8_24.dat", "r")
qmc_vmc_3_small = np.loadtxt(a_file)
a_file.close()

FigPlot(qmc_3,vmc_3,qmc_vmc_3,qmc_3_small,vmc_3_small,qmc_vmc_3_small)
FigPlot_2(qmc_3,vmc_3,qmc_vmc_3)

# %% [markdown]
# # 8x8, nh=32

# %%
a_file = open("nh32/QMC_Full/E_QMC_8_32.dat", "r")
qmc_4 = np.loadtxt(a_file)
a_file.close()

a_file = open("nh32/VMC_Full/E_VMC_8_32.dat", "r")
vmc_4 = np.loadtxt(a_file)
a_file.close()

a_file = open("nh32/QMC_VMC/E_QMC_VMC_8_32.dat", "r")
qmc_vmc_4 = np.loadtxt(a_file)
a_file.close()

# load smaller learning rate data for comparison
a_file = open("../../experiments/8x8/nh32/QMC_Full/E_QMC_8_32.dat", "r")
qmc_4_small = np.loadtxt(a_file)
a_file.close()

a_file = open("../../experiments/8x8/nh32/VMC_Full/E_VMC_8_32.dat", "r")
vmc_4_small = np.loadtxt(a_file)
a_file.close()

a_file = open("../../experiments/8x8/nh32/QMC_VMC/E_QMC_VMC_8_32.dat", "r")
qmc_vmc_4_small = np.loadtxt(a_file)
a_file.close()

FigPlot(qmc_4,vmc_4,qmc_vmc_4,qmc_4_small,vmc_4_small,qmc_vmc_4_small)
FigPlot_2(qmc_4,vmc_4,qmc_vmc_4)

# %% [markdown]
# # 8x8, nh=40

# %%
a_file = open("nh40/QMC_Full/E_QMC_8_40.dat", "r")
qmc_5 = np.loadtxt(a_file)
a_file.close()

a_file = open("nh40/VMC_Full/E_VMC_8_40.dat", "r")
vmc_5 = np.loadtxt(a_file)
a_file.close()

a_file = open("nh40/QMC_VMC/E_QMC_VMC_8_40.dat", "r")
qmc_vmc_5 = np.loadtxt(a_file)
a_file.close()

# load smaller learning rate data for comparison
a_file = open("../../experiments/8x8/nh40/QMC_Full/E_QMC_8_40.dat", "r")
qmc_5_small = np.loadtxt(a_file)
a_file.close()

a_file = open("../../experiments/8x8/nh40/VMC_Full/E_VMC_8_40.dat", "r")
vmc_5_small = np.loadtxt(a_file)
a_file.close()

a_file = open("../../experiments/8x8/nh40/QMC_VMC/E_QMC_VMC_8_40.dat", "r")
qmc_vmc_5_small = np.loadtxt(a_file)
a_file.close()

FigPlot(qmc_5,vmc_5,qmc_vmc_5,qmc_5_small,vmc_5_small,qmc_vmc_5_small)
FigPlot_2(qmc_5,vmc_5,qmc_vmc_5)
