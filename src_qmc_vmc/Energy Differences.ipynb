# %%
import numpy as np
import matplotlib.pyplot as plt

exactE_4     = -0.4534132086591546
exactE_8     = -0.40518005298872917
exactE_12    = -0.3884864748124427
exactE_16    = -0.380514770608724

# %% [markdown]
# # Read in data from experiments that train using VMC only and experiments that use out hybrid method

# %%
# 4x4, lr = 0.001
E_VMC_4_8        = np.loadtxt("experiments/4x4/nh8/VMC_Full/E_VMC_4_8.dat")
E_VMC_4_16       = np.loadtxt("experiments/4x4/nh16/VMC_Full/E_VMC_4_16.dat")
E_VMC_4_24       = np.loadtxt("experiments/4x4/nh24/VMC_Full/E_VMC_4_24.dat")
E_VMC_4_32       = np.loadtxt("experiments/4x4/nh32/VMC_Full/E_VMC_4_32.dat")
E_VMC_4_40       = np.loadtxt("experiments/4x4/nh40/VMC_Full/E_VMC_4_40.dat")
E_QMC_VMC_4_8    = np.loadtxt("experiments/4x4/nh8/QMC_VMC/E_QMC_VMC_4_8.dat")
E_QMC_VMC_4_16   = np.loadtxt("experiments/4x4/nh16/QMC_VMC/E_QMC_VMC_4_16.dat")
E_QMC_VMC_4_24   = np.loadtxt("experiments/4x4/nh24/QMC_VMC/E_QMC_VMC_4_24.dat")
E_QMC_VMC_4_32   = np.loadtxt("experiments/4x4/nh32/QMC_VMC/E_QMC_VMC_4_32.dat")
E_QMC_VMC_4_40   = np.loadtxt("experiments/4x4/nh40/QMC_VMC/E_QMC_VMC_4_40.dat")

# 8x8, lr = 0.001
E_VMC_8_8        = np.loadtxt("experiments/8x8/nh8/VMC_Full/E_VMC_8_8.dat")
E_VMC_8_16       = np.loadtxt("experiments/8x8/nh16/VMC_Full/E_VMC_8_16.dat")
E_VMC_8_24       = np.loadtxt("experiments/8x8/nh24/VMC_Full/E_VMC_8_24.dat")
E_VMC_8_32       = np.loadtxt("experiments/8x8/nh32/VMC_Full/E_VMC_8_32.dat")
E_VMC_8_40       = np.loadtxt("experiments/8x8/nh40/VMC_Full/E_VMC_8_40.dat")
E_QMC_VMC_8_8    = np.loadtxt("experiments/8x8/nh8/QMC_VMC/E_QMC_VMC_8_8.dat")
E_QMC_VMC_8_16   = np.loadtxt("experiments/8x8/nh16/QMC_VMC/E_QMC_VMC_8_16.dat")
E_QMC_VMC_8_24   = np.loadtxt("experiments/8x8/nh24/QMC_VMC/E_QMC_VMC_8_24.dat")
E_QMC_VMC_8_32   = np.loadtxt("experiments/8x8/nh32/QMC_VMC/E_QMC_VMC_8_32.dat")
E_QMC_VMC_8_40   = np.loadtxt("experiments/8x8/nh40/QMC_VMC/E_QMC_VMC_8_40.dat")

# 12x12, lr = 0.001
E_VMC_12_8        = np.loadtxt("experiments/12x12/nh8/VMC_Full/E_VMC_12_8.dat")
E_VMC_12_16       = np.loadtxt("experiments/12x12/nh16/VMC_Full/E_VMC_12_16.dat")
E_VMC_12_24       = np.loadtxt("experiments/12x12/nh24/VMC_Full/E_VMC_12_24.dat")
E_VMC_12_32       = np.loadtxt("experiments/12x12/nh32/VMC_Full/E_VMC_12_32.dat")
E_VMC_12_40       = np.loadtxt("experiments/12x12/nh40/VMC_Full/E_VMC_12_40.dat")
E_QMC_VMC_12_8    = np.loadtxt("experiments/12x12/nh8/QMC_VMC/E_QMC_VMC_12_8.dat")
E_QMC_VMC_12_16   = np.loadtxt("experiments/12x12/nh16/QMC_VMC/E_QMC_VMC_12_16.dat")
E_QMC_VMC_12_24   = np.loadtxt("experiments/12x12/nh24/QMC_VMC/E_QMC_VMC_12_24.dat")
E_QMC_VMC_12_32   = np.loadtxt("experiments/12x12/nh32/QMC_VMC/E_QMC_VMC_12_32.dat")
E_QMC_VMC_12_40   = np.loadtxt("experiments/12x12/nh40/QMC_VMC/E_QMC_VMC_12_40.dat")

# 16x16, lr = 0.001
E_VMC_16_8        = np.loadtxt("experiments/16x16/nh8/VMC_Full/E_VMC_16_8.dat")
E_VMC_16_16       = np.loadtxt("experiments/16x16/nh16/VMC_Full/E_VMC_16_16.dat")
E_VMC_16_24       = np.loadtxt("experiments/16x16/nh24/VMC_Full/E_VMC_16_24.dat")
E_VMC_16_32       = np.loadtxt("experiments/16x16/nh32/VMC_Full/E_VMC_16_32.dat")
E_VMC_16_40       = np.loadtxt("experiments/16x16/nh40/VMC_Full/E_VMC_16_40.dat")
E_QMC_VMC_16_8    = np.loadtxt("experiments/16x16/nh8/QMC_VMC/E_QMC_VMC_16_8.dat")
E_QMC_VMC_16_16   = np.loadtxt("experiments/16x16/nh16/QMC_VMC/E_QMC_VMC_16_16.dat")
E_QMC_VMC_16_24   = np.loadtxt("experiments/16x16/nh24/QMC_VMC/E_QMC_VMC_16_24.dat")
E_QMC_VMC_16_32   = np.loadtxt("experiments/16x16/nh32/QMC_VMC/E_QMC_VMC_16_32.dat")
E_QMC_VMC_16_40   = np.loadtxt("experiments/16x16/nh40/QMC_VMC/E_QMC_VMC_16_40.dat")

# 4x4, lr = 0.01
E_VMC_01_4_8    = np.loadtxt("experiments_lr0.01/4x4/nh8/VMC_Full/E_VMC_4_8.dat")
E_VMC_01_4_16   = np.loadtxt("experiments_lr0.01/4x4/nh16/VMC_Full/E_VMC_4_16.dat")
E_VMC_01_4_24   = np.loadtxt("experiments_lr0.01/4x4/nh24/VMC_Full/E_VMC_4_24.dat")
E_VMC_01_4_32   = np.loadtxt("experiments_lr0.01/4x4/nh32/VMC_Full/E_VMC_4_32.dat")
E_VMC_01_4_40   = np.loadtxt("experiments_lr0.01/4x4/nh40/VMC_Full/E_VMC_4_40.dat")
E_QMC_VMC_01_4_8    = np.loadtxt("experiments_lr0.01/4x4/nh8/QMC_VMC/E_QMC_VMC_4_8.dat")
E_QMC_VMC_01_4_16   = np.loadtxt("experiments_lr0.01/4x4/nh16/QMC_VMC/E_QMC_VMC_4_16.dat")
E_QMC_VMC_01_4_24   = np.loadtxt("experiments_lr0.01/4x4/nh24/QMC_VMC/E_QMC_VMC_4_24.dat")
E_QMC_VMC_01_4_32   = np.loadtxt("experiments_lr0.01/4x4/nh32/QMC_VMC/E_QMC_VMC_4_32.dat")
E_QMC_VMC_01_4_40   = np.loadtxt("experiments_lr0.01/4x4/nh40/QMC_VMC/E_QMC_VMC_4_40.dat")

# 8x8, lr = 0.01
E_VMC_01_8_8    = np.loadtxt("experiments_lr0.01/8x8/nh8/VMC_Full/E_VMC_8_8.dat")
E_VMC_01_8_16   = np.loadtxt("experiments_lr0.01/8x8/nh16/VMC_Full/E_VMC_8_16.dat")
E_VMC_01_8_24   = np.loadtxt("experiments_lr0.01/8x8/nh24/VMC_Full/E_VMC_8_24.dat")
E_VMC_01_8_32   = np.loadtxt("experiments_lr0.01/8x8/nh32/VMC_Full/E_VMC_8_32.dat")
E_VMC_01_8_40   = np.loadtxt("experiments_lr0.01/8x8/nh40/VMC_Full/E_VMC_8_40.dat")
E_QMC_VMC_01_8_8    = np.loadtxt("experiments_lr0.01/8x8/nh8/QMC_VMC/E_QMC_VMC_8_8.dat")
E_QMC_VMC_01_8_16   = np.loadtxt("experiments_lr0.01/8x8/nh16/QMC_VMC/E_QMC_VMC_8_16.dat")
E_QMC_VMC_01_8_24   = np.loadtxt("experiments_lr0.01/8x8/nh24/QMC_VMC/E_QMC_VMC_8_24.dat")
E_QMC_VMC_01_8_32   = np.loadtxt("experiments_lr0.01/8x8/nh32/QMC_VMC/E_QMC_VMC_8_32.dat")
E_QMC_VMC_01_8_40   = np.loadtxt("experiments_lr0.01/8x8/nh40/QMC_VMC/E_QMC_VMC_8_40.dat")

# 12x12, lr = 0.01
E_VMC_01_12_8    = np.loadtxt("experiments_lr0.01/12x12/nh8/VMC_Full/E_VMC_12_8.dat")
E_VMC_01_12_16   = np.loadtxt("experiments_lr0.01/12x12/nh16/VMC_Full/E_VMC_12_16.dat")
E_VMC_01_12_24   = np.loadtxt("experiments_lr0.01/12x12/nh24/VMC_Full/E_VMC_12_24.dat")
E_VMC_01_12_32   = np.loadtxt("experiments_lr0.01/12x12/nh32/VMC_Full/E_VMC_12_32.dat")
E_VMC_01_12_40   = np.loadtxt("experiments_lr0.01/12x12/nh40/VMC_Full/E_VMC_12_40.dat")
E_QMC_VMC_01_12_8    = np.loadtxt("experiments_lr0.01/12x12/nh8/QMC_VMC/E_QMC_VMC_12_8.dat")
E_QMC_VMC_01_12_16   = np.loadtxt("experiments_lr0.01/12x12/nh16/QMC_VMC/E_QMC_VMC_12_16.dat")
E_QMC_VMC_01_12_24   = np.loadtxt("experiments_lr0.01/12x12/nh24/QMC_VMC/E_QMC_VMC_12_24.dat")
E_QMC_VMC_01_12_32   = np.loadtxt("experiments_lr0.01/12x12/nh32/QMC_VMC/E_QMC_VMC_12_32.dat")
E_QMC_VMC_01_12_40   = np.loadtxt("experiments_lr0.01/12x12/nh40/QMC_VMC/E_QMC_VMC_12_40.dat")

# 16x16, lr = 0.01
E_VMC_01_16_8    = np.loadtxt("experiments_lr0.01/16x16/nh8/VMC_Full/E_VMC_16_8.dat")
E_VMC_01_16_16   = np.loadtxt("experiments_lr0.01/16x16/nh16/VMC_Full/E_VMC_16_16.dat")
E_VMC_01_16_24   = np.loadtxt("experiments_lr0.01/16x16/nh24/VMC_Full/E_VMC_16_24.dat")
E_VMC_01_16_32   = np.loadtxt("experiments_lr0.01/16x16/nh32/VMC_Full/E_VMC_16_32.dat")
E_VMC_01_16_40   = np.loadtxt("experiments_lr0.01/16x16/nh40/VMC_Full/E_VMC_16_40.dat")
E_QMC_VMC_01_16_8    = np.loadtxt("experiments_lr0.01/16x16/nh8/QMC_VMC/E_QMC_VMC_16_8.dat")
E_QMC_VMC_01_16_16   = np.loadtxt("experiments_lr0.01/16x16/nh16/QMC_VMC/E_QMC_VMC_16_16.dat")
E_QMC_VMC_01_16_24   = np.loadtxt("experiments_lr0.01/16x16/nh24/QMC_VMC/E_QMC_VMC_16_24.dat")
E_QMC_VMC_01_16_32   = np.loadtxt("experiments_lr0.01/16x16/nh32/QMC_VMC/E_QMC_VMC_16_32.dat")
E_QMC_VMC_01_16_40   = np.loadtxt("experiments_lr0.01/16x16/nh40/QMC_VMC/E_QMC_VMC_16_40.dat")

# %% [markdown]
# # Compute Energy Differences

# %%
def E_diff(E_VMC, E_QMC):
    return E_VMC - E_QMC

# %%
# 4x4, lr = 0.001
diff_4_8      = E_diff(E_VMC_4_8, E_QMC_VMC_4_8)
diff_4_16     = E_diff(E_VMC_4_16, E_QMC_VMC_4_16)
diff_4_24     = E_diff(E_VMC_4_24, E_QMC_VMC_4_24)
diff_4_32     = E_diff(E_VMC_4_32, E_QMC_VMC_4_32)
diff_4_40     = E_diff(E_VMC_4_40, E_QMC_VMC_4_40)

# 8x8, lr = 0.001
diff_8_8      = E_diff(E_VMC_8_8, E_QMC_VMC_8_8)
diff_8_16     = E_diff(E_VMC_8_16, E_QMC_VMC_8_16)
diff_8_24     = E_diff(E_VMC_8_24, E_QMC_VMC_8_24)
diff_8_32     = E_diff(E_VMC_8_32, E_QMC_VMC_8_32)
diff_8_40     = E_diff(E_VMC_8_40, E_QMC_VMC_8_40)

# 12x12, lr = 0.001
diff_12_8      = E_diff(E_VMC_12_8, E_QMC_VMC_12_8)
diff_12_16     = E_diff(E_VMC_12_16, E_QMC_VMC_12_16)
diff_12_24     = E_diff(E_VMC_12_24, E_QMC_VMC_12_24)
diff_12_32     = E_diff(E_VMC_12_32, E_QMC_VMC_12_32)
diff_12_40     = E_diff(E_VMC_12_40, E_QMC_VMC_12_40)

#16x16, lr = 0.001
diff_16_8      = E_diff(E_VMC_16_8, E_QMC_VMC_16_8)
diff_16_16     = E_diff(E_VMC_16_16, E_QMC_VMC_16_16)
diff_16_24     = E_diff(E_VMC_16_24, E_QMC_VMC_16_24)
diff_16_32     = E_diff(E_VMC_16_32, E_QMC_VMC_16_32)
diff_16_40     = E_diff(E_VMC_16_40, E_QMC_VMC_16_40)

# 4x4, lr = 0.01
diff_01_4_8      = E_diff(E_VMC_01_4_8, E_QMC_VMC_01_4_8)
diff_01_4_16     = E_diff(E_VMC_01_4_16, E_QMC_VMC_01_4_16)
diff_01_4_24     = E_diff(E_VMC_01_4_24, E_QMC_VMC_01_4_24)
diff_01_4_32     = E_diff(E_VMC_01_4_32, E_QMC_VMC_01_4_32)
diff_01_4_40     = E_diff(E_VMC_01_4_40, E_QMC_VMC_01_4_40)

# 8x8, lr = 0.01
diff_01_8_8      = E_diff(E_VMC_01_8_8, E_QMC_VMC_01_8_8)
diff_01_8_16     = E_diff(E_VMC_01_8_16, E_QMC_VMC_01_8_16)
diff_01_8_24     = E_diff(E_VMC_01_8_24, E_QMC_VMC_01_8_24)
diff_01_8_32     = E_diff(E_VMC_01_8_32, E_QMC_VMC_01_8_32)
diff_01_8_40     = E_diff(E_VMC_01_8_40, E_QMC_VMC_01_8_40)

# 12x12, lr = 0.01
diff_01_12_8      = E_diff(E_VMC_01_12_8, E_QMC_VMC_01_12_8)
diff_01_12_16     = E_diff(E_VMC_01_12_16, E_QMC_VMC_01_12_16)
diff_01_12_24     = E_diff(E_VMC_01_12_24, E_QMC_VMC_01_12_24)
diff_01_12_32     = E_diff(E_VMC_01_12_32, E_QMC_VMC_01_12_32)
diff_01_12_40     = E_diff(E_VMC_01_12_40, E_QMC_VMC_01_12_40)

#16x16, lr = 0.01
diff_01_16_8      = E_diff(E_VMC_01_16_8, E_QMC_VMC_01_16_8)
diff_01_16_16     = E_diff(E_VMC_01_16_16, E_QMC_VMC_01_16_16)
diff_01_16_24     = E_diff(E_VMC_01_16_24, E_QMC_VMC_01_16_24)
diff_01_16_32     = E_diff(E_VMC_01_16_32[:3460], E_QMC_VMC_01_16_32[:3460])
diff_01_16_40     = E_diff(E_VMC_01_16_40, E_QMC_VMC_01_16_40)

# %% [markdown]
# # Energy difference plotting function

# %%
def DiffPlot(N,lr,diff_8,diff_16,diff_24,diff_32,diff_40,xlim,ylim):
    'plots the energy differences for each nh'
    
    fig = plt.figure(1,figsize=(6,4), dpi=120, facecolor='w', edgecolor='k')
     
    plt.plot(diff_8,marker='o',markersize=1,linewidth=0.0,markevery=1,label= 'nh = 8')
    plt.plot(diff_16,marker='o',markersize=1,linewidth=0.0,markevery=1,label= 'nh = 16')
    plt.plot(diff_24,marker='o',markersize=1,linewidth=0.0,markevery=1,label= 'nh = 24')
    plt.plot(diff_32,marker='o',markersize=1,linewidth=0.0,markevery=1,label= 'nh = 32')
    plt.plot(diff_40,marker='o',markersize=1,linewidth=0.0,markevery=1,label= 'nh = 40')
    plt.hlines(0,0, 4000 ,linestyle="--",label="Exact")
    plt.xlabel("Step",fontsize=15)
    plt.ylabel("$\\Delta \\langle H \\rangle$",fontsize=20)
    plt.title("{} x {} Lattice, Learning Rate = {}".format(N,N,lr))
    plt.legend(loc="best")
    plt.xlim(xlim[0],xlim[1])
    plt.ylim(ylim[0],ylim[1])

    plt.show()

# %% [markdown]
# ### 4x4, lr = 0.001

# %%
DiffPlot(4,0.001,diff_4_8,diff_4_16,diff_4_24,diff_4_32,diff_4_40,[0,2000],[-0.1,0.5])

# %% [markdown]
# ### 4x4, lr = 0.01

# %%
DiffPlot(4,0.01,diff_01_4_8,diff_01_4_16,diff_01_4_24,diff_01_4_32,diff_01_4_40,[0,500],[-0.1,0.5])

# %% [markdown]
# ### 8x8, lr = 0.001

# %%
DiffPlot(8,0.001,diff_8_8,diff_8_16,diff_8_24,diff_8_32,diff_8_40,[0,1000],[-0.1,0.5])

# %% [markdown]
# ### 8x8, lr = 0.01

# %%
DiffPlot(8,0.01,diff_01_8_8,diff_01_8_16,diff_01_8_24,diff_01_8_32,diff_01_8_40,[0,1000],[-0.1,0.5])

# %% [markdown]
# ### 12x12, lr = 0.001

# %%
DiffPlot(12,0.001,diff_12_8,diff_12_16,diff_12_24,diff_12_32,diff_12_40,[0,2000],[-0.1,0.5])

# %% [markdown]
# ### 12x12, lr = 0.01

# %%
DiffPlot(12,0.01,diff_01_12_8,diff_01_12_16,diff_01_12_24,diff_01_12_32,diff_01_12_40,[0,2000],[-0.1,0.5])

# %% [markdown]
# ### 16x16, lr = 0.001 (waiting on data)

# %%
DiffPlot(16,0.001,diff_16_8,diff_16_16,diff_16_24,diff_16_32,diff_16_40,[0,4000],[-0.1,0.5])

# %% [markdown]
# ### 16x16, lr = 0.01 (waiting on data)

# %%
DiffPlot(16,0.01,diff_01_16_8,diff_01_16_16,diff_01_16_24,diff_01_16_32,diff_01_16_40,[0,2000],[-0.1,0.5])
